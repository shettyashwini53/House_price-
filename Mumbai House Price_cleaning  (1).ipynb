# %%
import numpy as np
import pandas as pd

# %%
data= pd.read_csv(r"C:\Users\Ashwini Shetty\Desktop\PyGWalker - Python Data Visualization tool  Streamlit Integration\Mumbai House Prices.csv", delimiter=",", low_memory=True)
data.head(70)
# Out:
#     bhk       type                              locality  area  price  \
# 0     3  Apartment   Lak And Hanware The Residency Tower   685   2.50
# 1     2  Apartment     Radheya Sai Enclave Building No 2   640  52.51
# 2     2  Apartment                         Romell Serene   610   1.73
# 3     2  Apartment  Soundlines Codename Urban Rainforest   876  59.98
# 4     2  Apartment                         Origin Oriana   659  94.11
# ..  ...        ...                                   ...   ...    ...
# 65    1  Apartment                     Godrej Urban Park   450   1.39
# 66    3  Apartment              Aurum Q Island R4 AND R5  1259   2.80
# 67    2  Apartment   Raymond Raymond Realty TenX Habitat   515   1.24
# 68    3  Apartment                       Asshna Seabliss  1274   4.20
# 69    2  Apartment                      Mayfair The View   582   1.49
#
#    price_unit          region              status  age
# 0          Cr    Andheri West       Ready to move  New
# 1           L    Naigaon East  Under Construction  New
# 2          Cr   Borivali West  Under Construction  New
# 3           L          Panvel  Under Construction  New
# 4           L  Mira Road East  Under Construction  New
# ..        ...             ...                 ...  ...
# 65         Cr           Powai  Under Construction  New
# 66         Cr        Ghansoli       Ready to move  New
# 67         Cr      Thane West  Under Construction  New
# 68         Cr    Andheri West  Under Construction  New
# 69         Cr        Vikhroli  Under Construction  New
#
# [70 rows x 9 columns]

# %%
data.shape
# Out:
# (76038, 9)

# %%
data.isnull().sum()
# Out:
# bhk           0
# type          0
# locality      0
# area          0
# price         0
# price_unit    0
# region        0
# status        0
# age           0
# dtype: int64

# %%
# Remove duplicate rows
data = data.drop_duplicates()

# Reset index after removing duplicates
data.reset_index(drop=True, inplace=True)

# %%
data.shape
# Out:
# (55726, 9)

# %%
data.head(30)
# Out:
#     bhk              type                                           locality  \
# 0     3         Apartment                Lak And Hanware The Residency Tower
# 1     2         Apartment                  Radheya Sai Enclave Building No 2
# 2     2         Apartment                                      Romell Serene
# 3     2         Apartment               Soundlines Codename Urban Rainforest
# 4     2         Apartment                                      Origin Oriana
# 5     2         Apartment                       Bhoomi Simana Wing A Phase 1
# 6     5             Villa                                     Agami Estancia
# 7     3         Apartment                                    Sanghvi Infenia
# 8     1         Apartment                              Shubh Shreeji Heights
# 9     2         Apartment                         Aplite Greenstone Heritage
# 10    1  Studio Apartment                               A Plus Golden Corner
# 11    2         Apartment                                    Unimont Imperia
# 12    3         Apartment                                    Aayush Gulmohar
# 13    2         Apartment                                     Roswalt Zaiden
# 14    1         Apartment                        Angel Falcon Emerald Dunlin
# 15    2         Apartment  Proviso Sai Proviso Icon Greater Kharghar Road...
# 16    1         Apartment                                  Godrej Urban Park
# 17    3         Apartment                           Aurum Q Island R4 AND R5
# 18    2         Apartment                Raymond Raymond Realty TenX Habitat
# 19    3         Apartment                                    Asshna Seabliss
# 20    2         Apartment                                   Mayfair The View
# 21    1         Apartment                      Shakti Shree Siddhivinayak II
# 22    1         Apartment                                    Vardhan Heights
# 23    1         Apartment                           Puraniks Unicorn Phase 1
# 24    2         Apartment                                   Pyramid Elements
# 25    2         Apartment                            Tharwani Meghna Montana
# 26    2         Apartment                         Dev Drashti Empire Phase 1
# 27    2         Apartment                 B G Shirke Monte Verita West Tower
# 28    1         Apartment                                      Jindal Avenue
# 29    2         Apartment                                      Walekar Homes
#
#     area  price price_unit           region              status  age
# 0    685   2.50         Cr     Andheri West       Ready to move  New
# 1    640  52.51          L     Naigaon East  Under Construction  New
# 2    610   1.73         Cr    Borivali West  Under Construction  New
# 3    876  59.98          L           Panvel  Under Construction  New
# 4    659  94.11          L   Mira Road East  Under Construction  New
# 5    826   3.30         Cr            Parel  Under Construction  New
# 6   2921   1.99         Cr           Boisar  Under Construction  New
# 7    778   2.89         Cr   Santacruz East  Under Construction  New
# 8    396  29.84          L    Badlapur East       Ready to move  New
# 9    671   2.72         Cr             Fort  Under Construction  New
# 10   502  16.56          L    Badlapur West  Under Construction  New
# 11   950  41.75          L          Khopoli  Under Construction  New
# 12   753   1.77         Cr          Chembur  Under Construction  New
# 13   605   1.55         Cr  Jogeshwari West  Under Construction  New
# 14   557  58.50          L            Vasai  Under Construction  New
# 15   635  83.00          L        Kalamboli  Under Construction  New
# 16   450   1.39         Cr            Powai  Under Construction  New
# 17  1259   2.80         Cr         Ghansoli       Ready to move  New
# 18   555   1.42         Cr       Thane West  Under Construction  New
# 19  1274   4.20         Cr     Andheri West  Under Construction  New
# 20   582   1.49         Cr         Vikhroli  Under Construction  New
# 21   483  37.52          L         Bhiwandi  Under Construction  New
# 22   320  69.90          L          Chembur  Under Construction  New
# 23   396  42.99          L       Thane West  Under Construction  New
# 24   638   1.26         Cr           Airoli  Under Construction  New
# 25  1047  49.58          L   Ambernath West  Under Construction  New
# 26  1080  57.24          L         Bhiwandi       Ready to move  New
# 27   555   1.31         Cr    Borivali East  Under Construction  New
# 28   261  47.50          L           Panvel  Under Construction  New
# 29   594  34.50          L   Ambernath West       Ready to move  New

# %%
data["price_unit"].unique()
# Out:
# array(['Cr', 'L'], dtype=object)

# %%
data["price_unit"]=data["price_unit"].replace({"Cr":10000000,"L":100000})

# %%
data["price_unit"].unique()
# Out:
# array([10000000,   100000], dtype=int64)

# %%
# Perform element-wise multiplication of the columns
data['price'] = data['price'] * data['price_unit']

# If you want to keep only the merged column and drop the original columns, you can do:
data.drop(['price_unit'], axis=1, inplace=True)

# %%
data.head(10)
# Out:
#    bhk       type                              locality  area       price  \
# 0    3  Apartment   Lak And Hanware The Residency Tower   685  25000000.0
# 1    2  Apartment     Radheya Sai Enclave Building No 2   640   5251000.0
# 2    2  Apartment                         Romell Serene   610  17300000.0
# 3    2  Apartment  Soundlines Codename Urban Rainforest   876   5998000.0
# 4    2  Apartment                         Origin Oriana   659   9411000.0
# 5    2  Apartment          Bhoomi Simana Wing A Phase 1   826  33000000.0
# 6    5      Villa                        Agami Estancia  2921  19900000.0
# 7    3  Apartment                       Sanghvi Infenia   778  28900000.0
# 8    1  Apartment                 Shubh Shreeji Heights   396   2984000.0
# 9    2  Apartment            Aplite Greenstone Heritage   671  27200000.0
#
#            region              status  age
# 0    Andheri West       Ready to move  New
# 1    Naigaon East  Under Construction  New
# 2   Borivali West  Under Construction  New
# 3          Panvel  Under Construction  New
# 4  Mira Road East  Under Construction  New
# 5           Parel  Under Construction  New
# 6          Boisar  Under Construction  New
# 7  Santacruz East  Under Construction  New
# 8   Badlapur East       Ready to move  New
# 9            Fort  Under Construction  New

# %%
data.to_excel("ddd.xlsx",index=False)
